# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Feature_engineering_tutorial_python_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from google.colab import drive
# Mounting the drive for loading the data
drive.mount('/content/drive')
# !ls '/content/drive/MyDrive/py-master/ML/FeatureEngineering/3_outlier_IQR/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 3_outliers_iqr.ipynb  Exercise	heights.csv

# %%
# reading  data in the file
df = pd.read_csv('/content/drive/MyDrive/py-master/ML/FeatureEngineering/3_outlier_IQR/heights.csv')
df.head(3)
# Out:
#     name  height
# 0  mohan     1.2
# 1  maria     2.3
# 2  sakib     4.9

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.describe()
# Out:
#           height
# count  20.000000
# mean    8.390000
# std     8.782812
# min     1.200000
# 25%     5.350000
# 50%     5.700000
# 75%     6.275000
# max    40.200000

# %%
Q1 = df.height.quantile(0.25)
Q3 = df.height.quantile(0.75)
IQR = Q3-Q1
lowerlimit = Q1-1.5*IQR
upperlimit = Q3+1.5*IQR
lowerlimit,upperlimit
# Out:
# (3.962500000000001, 7.6625)

# %%
df.shape
# Out:
# (20, 2)

# %%
df1 = df[(df.height>lowerlimit)&(df.height<upperlimit)]
df1.shape # 5 outliers removed
# Out:
# (15, 2)
