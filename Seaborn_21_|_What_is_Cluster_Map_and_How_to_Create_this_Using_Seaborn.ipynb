# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Seaborn_21_%7C_What_is_Cluster_Map_and_How_to_Create_this_Using_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
from google.colab.patches import cv2_imshow
import os

drive.mount('/content/drive/')
# !ls '/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/'
mart = pd.read_csv('/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/train.csv')
mart['Tier'] = mart['Outlet_Location_Type'].str.strip().str[-1]
mart.head(5)
# Out:
# Mounted at /content/drive/
# supermarket_sales.xlsx	train.csv
#   Item_ID     Item_W  ...        Sales  Tier
# 0   FDN27   9.437510  ...   897.085562     1
# 1   FDW35   9.033762  ...  1639.303513     2
# 2   FDS28  20.884849  ...  2664.773737     1
# 3   FDC09  19.976300  ...   440.859592     3
# 4   FDX04  10.824812  ...    29.807098     1
#
# [5 rows x 10 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
martpiv = mart.pivot_table(index='Outlet_Year', columns='Outlet_Size',values='Sales')
martpiv
martpiv= martpiv.fillna(100)

# %%
sns.clustermap(data=martpiv, col_cluster=False, row_cluster=True,cmap='cool', annot=True, fmt='.0f', standard_scale=1, linewidth=0.5)
