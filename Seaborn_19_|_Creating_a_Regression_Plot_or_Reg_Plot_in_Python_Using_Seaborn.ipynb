# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Seaborn_19_%7C_Creating_a_Regression_Plot_or_Reg_Plot_in_Python_Using_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from google.colab import drive
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
from google.colab.patches import cv2_imshow
import os

drive.mount('/content/drive/')
# !ls '/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/'
mart = pd.read_csv('/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/train.csv')
mart['Tier'] = mart['Outlet_Location_Type'].str.strip().str[-1]
mart.head(5)
# Out:
# Mounted at /content/drive/
# supermarket_sales.xlsx	train.csv
#   Item_ID     Item_W  ...        Sales  Tier
# 0   FDN27   9.437510  ...   897.085562     1
# 1   FDW35   9.033762  ...  1639.303513     2
# 2   FDS28  20.884849  ...  2664.773737     1
# 3   FDC09  19.976300  ...   440.859592     3
# 4   FDX04  10.824812  ...    29.807098     1
#
# [5 rows x 10 columns]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
tips=sns.load_dataset('tips')
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(data=tips, x='total_bill', y='tip')

# %%
sns.regplot(data=tips, x='total_bill', y='tip',ci=95, marker='+', color='blue', line_kws={'color':'red','linestyle':'--'})
