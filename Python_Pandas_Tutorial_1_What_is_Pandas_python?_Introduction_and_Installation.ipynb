# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Python_Pandas_Tutorial_1_What_is_Pandas_python%3F_Introduction_and_Installation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import os

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/py-master/pandas/1_intro'
# Out:
# nyc_weather.csv  Pandas_introduction.ipynb  pandas_intro.py

# %%
df = pd.read_csv('/content/drive/MyDrive/py-master/pandas/1_intro/nyc_weather.csv')
df.head(5)
# Out:
#         EST  Temperature  DewPoint  ...  CloudCover  Events  WindDirDegrees
# 0  1/1/2016           38        23  ...           5     NaN             281
# 1  1/2/2016           36        18  ...           3     NaN             275
# 2  1/3/2016           40        21  ...           1     NaN             277
# 3  1/4/2016           25         9  ...           3     NaN             345
# 4  1/5/2016           20        -3  ...           0     NaN             333
#
# [5 rows x 11 columns]

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df['EST'][df['Events']=='Rain'] # to find out on which days did it rain
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df['WindSpeedMPH'].fillna(0).mean()
# Out:
# 6.225806451612903
