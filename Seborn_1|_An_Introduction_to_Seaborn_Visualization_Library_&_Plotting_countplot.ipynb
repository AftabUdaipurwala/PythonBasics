# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Seborn_1%7C_An_Introduction_to_Seaborn_Visualization_Library_%26_Plotting_countplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as py
import pandas as pd
from google.colab import drive
from scipy import stats
import warnings
warnings.filterwarnings("ignore")
from google.colab.patches import cv2_imshow
import os

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !ls '/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/'
# Out:
# supermarket_sales.xlsx

# %%
mart = pd.read_excel('/content/drive/MyDrive/Data Science Learning Path/Python Seaborn Library/supermarket_sales.xlsx')

# %%
mart.head(5)
# Out:
#     Invoice ID Branch      City  ... gross margin percentage gross income Rating
# 0  692-92-5582      B  Mandalay  ...                4.761905        8.226    5.9
# 1  351-62-0822      B  Mandalay  ...                4.761905        2.896    4.5
# 2  529-56-3974      B  Mandalay  ...                4.761905        5.102    6.8
# 3  299-46-1805      B  Mandalay  ...                4.761905       28.116    4.5
# 4  319-50-3348      B  Mandalay  ...                4.761905        4.030    4.4
#
# [5 rows x 17 columns]

# %%
mart.shape
# Out:
# (1000, 17)

# %%
mart.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %% [markdown]
# # ***Create Count Plot***

# %%
sns.countplot(x='Gender', data=mart,palette='husl')
