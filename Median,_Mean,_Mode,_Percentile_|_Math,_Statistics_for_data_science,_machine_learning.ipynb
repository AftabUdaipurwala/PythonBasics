# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Median%2C_Mean%2C_Mode%2C_Percentile_%7C_Math%2C_Statistics_for_data_science%2C_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/math-for-machine-learning-main/4_mean_percentile'
# Out:
# Exercise  income.csv  median_percentile.ipynb

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/math-for-machine-learning-main/4_mean_percentile/income.csv')
df.head(7)
# Out:
#         Name  Monthly Income ($)
# 0        Rob                5000
# 1      Rafiq                6000
# 2       Nina                4000
# 3      Sofia                7500
# 4      Mohan                8000
# 5        Tao                7000
# 6  Elon Musk            10000000

# %%
df.shape
# Out:
# (7, 2)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df.describe()
# Out:
#        Monthly Income ($)
# count        7.000000e+00
# mean         1.433929e+06
# std          3.777283e+06
# min          4.000000e+03
# 25%          5.500000e+03
# 50%          7.000000e+03
# 75%          7.750000e+03
# max          1.000000e+07

# %%
df2 = df[df['Monthly Income ($)']<df['Monthly Income ($)'].quantile(0.99)]

# %%
df2
# Out:
#     Name  Monthly Income ($)
# 0    Rob                5000
# 1  Rafiq                6000
# 2   Nina                4000
# 3  Sofia                7500
# 4  Mohan                8000
# 5    Tao                7000

# %%
df['Monthly Income ($)'].quantile(0.25,interpolation='lower')
# Out:
# 5000

# %%
df['Monthly Income ($)'].quantile(0.25,interpolation='higher')
# Out:
# 6000

# %%
df['Monthly Income ($)'].quantile(0.25,interpolation='linear')
# Out:
# 5500.0

# %%
# Creating null values in dataset and then replacing it with Median
df['Monthly Income ($)'][3]=np.NaN

# %%
df
# Out:
#         Name  Monthly Income ($)
# 0        Rob              5000.0
# 1      Rafiq              6000.0
# 2       Nina              4000.0
# 3      Sofia                 NaN
# 4      Mohan              8000.0
# 5        Tao              7000.0
# 6  Elon Musk          10000000.0

# %%
df= df.fillna(df['Monthly Income ($)'].quantile(0.5, interpolation='linear'))
df
# Out:
#         Name  Monthly Income ($)
# 0        Rob              5000.0
# 1      Rafiq              6000.0
# 2       Nina              4000.0
# 3      Sofia              6500.0
# 4      Mohan              8000.0
# 5        Tao              7000.0
# 6  Elon Musk          10000000.0
