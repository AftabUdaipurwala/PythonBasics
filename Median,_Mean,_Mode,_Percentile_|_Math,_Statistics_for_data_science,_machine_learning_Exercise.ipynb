# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Median%2C_Mean%2C_Mode%2C_Percentile_%7C_Math%2C_Statistics_for_data_science%2C_machine_learning_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/math-for-machine-learning-main/4_mean_percentile/Exercise'
# Out:
# AB_NYC_2019.csv  exercise.md  percentile_exercise_solution.ipynb

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/math-for-machine-learning-main/4_mean_percentile/Exercise/AB_NYC_2019.csv')
df.head(7)
# Out:
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
# 5  5099  ...              129
# 6  5121  ...                0
#
# [7 rows x 16 columns]

# %%
sns.histplot(df.price, kde=True)

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
LSL,USL = df.price.quantile(0.05),df.price.quantile(0.95)
LSL,USL
# Out:
# (40.0, 355.0)

# %%
df2 = df[(df.price>LSL)&(df.price<USL)]
df2.shape
# Out:
# (43631, 16)

# %%
sns.histplot(df2.price, kde=True)
