# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/What_is_logarithm%3F_%7C_Math%2C_Statistics_for_data_science%2C_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/math-for-machine-learning-main/1_log/'
# Out:
# income.csv  logarithm_in_data_analysis.ipynb  revenue.csv

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/math-for-machine-learning-main/1_log/revenue.csv')
df.head()
# Out:
#          company  revenue
# 0         Tesla      31.0
# 1           UBER     11.0
# 2         Amazon    386.0
# 3  Jindal  Steel      4.7
# 4      Axis Bank      5.6

# %%
df.plot(x='company', y='revenue', kind='bar')

# %%
df.plot(x='company', y='revenue', kind='bar', logy=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
