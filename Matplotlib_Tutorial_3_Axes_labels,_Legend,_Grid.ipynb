# %% [markdown]
# <a href="https://colab.research.google.com/github/AftabUdaipurwala/PythonBasics/blob/main/Matplotlib_Tutorial_3_Axes_labels%2C_Legend%2C_Grid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
days=np.array([1,2,3,4,5,6,7])
maxt=np.array([51,54,67,34,56,50,48])
mint=np.array([47,34,45,21,50,30,40])
avert=(mint+maxt)/2

# %%
plt.xlabel('Day of Week')
plt.ylabel('Temperature')
plt.title('Temperature Trend')

plt.plot(days,maxt, label='Max Temp')
plt.plot(days,mint, label='Min Temp')
plt.plot(days,avert,label='Average Temp')

plt.legend(loc='upper right', shadow=True, fontsize='small')
plt.grid()
